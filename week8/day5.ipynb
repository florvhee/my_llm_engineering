# %% [markdown]
# # The Price is Right
#
# The final step is to build a User Interface
#
# We will use more advanced aspects of Gradio - building piece by piece.

# %%
import gradio as gr
from deal_agent_framework import DealAgentFramework
from agents.deals import Opportunity, Deal

# %%
with gr.Blocks(title="The Price is Right", fill_width=True) as ui:

    with gr.Row():
        gr.Markdown('<div style="text-align: center;font-size:24px">The Price is Right - Deal Hunting Agentic AI</div>')
    with gr.Row():
        gr.Markdown('<div style="text-align: center;font-size:14px">Autonomous agent framework that finds online deals, collaborating with a proprietary fine-tuned LLM deployed on Modal, and a RAG pipeline with a frontier model and Chroma.</div>')
        

ui.launch(inbrowser=True)
# Out:
# * Running on local URL:  http://127.0.0.1:7860
# * To create a public link, set `share=True` in `launch()`.
# <div><iframe src="http://127.0.0.1:7860/" width="100%" height="500" allow="autoplay; camera; microphone; clipboard-read; clipboard-write;" frameborder="0" allowfullscreen></iframe></div>

# %%
# Updated to change from height to max_height due to change in Gradio v5
# With much thanks to student Ed B. for raising this

with gr.Blocks(title="The Price is Right", fill_width=True) as ui:

    initial_deal = Deal(product_description="Example description", price=100.0, url="https://cnn.com")
    initial_opportunity = Opportunity(deal=initial_deal, estimate=200.0, discount=100.0)
    opportunities = gr.State([initial_opportunity])

    def get_table(opps):
        return [[opp.deal.product_description, opp.deal.price, opp.estimate, opp.discount, opp.deal.url] for opp in opps]

    with gr.Row():
        gr.Markdown('<div style="text-align: center;font-size:24px">"The Price is Right" - Deal Hunting Agentic AI</div>')
    with gr.Row():
        gr.Markdown('<div style="text-align: center;font-size:14px">Deals surfaced so far:</div>')
    with gr.Row():
        opportunities_dataframe = gr.Dataframe(
            headers=["Description", "Price", "Estimate", "Discount", "URL"],
            wrap=True,
            column_widths=[4, 1, 1, 1, 2],
            row_count=10,
            col_count=5,
            max_height=400,
        )

    ui.load(get_table, inputs=[opportunities], outputs=[opportunities_dataframe])

ui.launch(inbrowser=True)

# %%
agent_framework = DealAgentFramework()
agent_framework.init_agents_as_needed()

with gr.Blocks(title="The Price is Right", fill_width=True) as ui:

    initial_deal = Deal(product_description="Example description", price=100.0, url="https://cnn.com")
    initial_opportunity = Opportunity(deal=initial_deal, estimate=200.0, discount=100.0)
    opportunities = gr.State([initial_opportunity])

    def get_table(opps):
        return [[opp.deal.product_description, opp.deal.price, opp.estimate, opp.discount, opp.deal.url] for opp in opps]

    def do_select(opportunities, selected_index: gr.SelectData):
        row = selected_index.index[0]
        opportunity = opportunities[row]
        agent_framework.planner.messenger.alert(opportunity)

    with gr.Row():
        gr.Markdown('<div style="text-align: center;font-size:24px">"The Price is Right" - Deal Hunting Agentic AI</div>')
    with gr.Row():
        gr.Markdown('<div style="text-align: center;font-size:14px">Deals surfaced so far:</div>')
    with gr.Row():
        opportunities_dataframe = gr.Dataframe(
            headers=["Description", "Price", "Estimate", "Discount", "URL"],
            wrap=True,
            column_widths=[4, 1, 1, 1, 2],
            row_count=10,
            col_count=5,
            max_height=400,
        )

    ui.load(get_table, inputs=[opportunities], outputs=[opportunities_dataframe])
    opportunities_dataframe.select(do_select, inputs=[opportunities], outputs=[])

ui.launch(inbrowser=True)

# %% [markdown]
# # Time for the code
#
# And now we'll move to the price_is_right.py code, followed by price_is_right_final.py

# %% [markdown]
# # Running the final product
#
# ## Just hit shift + enter in the next cell, and let the deals flow in!!
#
# Note that the Frontier Agent will use DeepSeek if there's a DEEPSEEK_API_KEY in your .env file, otherwise gpt-4o-mini.

# %%
# !python price_is_right_final.py
# Out:
# * Running on local URL:  http://127.0.0.1:7861
# * To create a public link, set `share=True` in `launch()`.
# [2025-11-20 18:14:44 +0100] [Agents] [INFO] [Agent Framework] Initializing Agent Framework
# [2025-11-20 18:14:44 +0100] [Agents] [INFO] [Agent Framework] Initializing Agent Framework
# [2025-11-20 18:14:44 +0100] [Agents] [INFO] [Planning Agent] Planning Agent is initializing
# [2025-11-20 18:14:44 +0100] [Agents] [INFO] [Planning Agent] Planning Agent is initializing
# [2025-11-20 18:14:44 +0100] [Agents] [INFO] [Scanner Agent] Scanner Agent is initializing
# [2025-11-20 18:14:44 +0100] [Agents] [INFO] [Scanner Agent] Scanner Agent is initializing
# [2025-11-20 18:14:44 +0100] [Agents] [INFO] [Agent Framework] Initializing Agent Framework
# [2025-11-20 18:14:44 +0100] [Agents] [INFO] [Agent Framework] Initializing Agent Framework
# [2025-11-20 18:14:44 +0100] [Agents] [INFO] [Planning Agent] Planning Agent is initializing
# [2025-11-20 18:14:44 +0100] [Agents] [INFO] [Planning Agent] Planning Agent is initializing
# [2025-11-20 18:14:44 +0100] [Agents] [INFO] [Scanner Agent] Scanner Agent is initializing
# [2025-11-20 18:14:44 +0100] [Agents] [INFO] [Scanner Agent] Scanner Agent is initializing
# [2025-11-20 18:14:44 +0100] [Agents] [INFO] [Scanner Agent] Scanner Agent is ready
# [2025-11-20 18:14:44 +0100] [Agents] [INFO] [Scanner Agent] Scanner Agent is ready
# [2025-11-20 18:14:44 +0100] [Agents] [INFO] [Scanner Agent] Scanner Agent is ready
# [2025-11-20 18:14:44 +0100] [Agents] [INFO] [Scanner Agent] Scanner Agent is ready
# [2025-11-20 18:14:44 +0100] [Agents] [INFO] [Ensemble Agent] Initializing Ensemble Agent
# [2025-11-20 18:14:44 +0100] [Agents] [INFO] [Ensemble Agent] Initializing Ensemble Agent
# [2025-11-20 18:14:44 +0100] [Agents] [INFO] [Ensemble Agent] Initializing Ensemble Agent
# [2025-11-20 18:14:44 +0100] [Agents] [INFO] [Ensemble Agent] Initializing Ensemble Agent
# [2025-11-20 18:14:44 +0100] [Agents] [INFO] [Specialist Agent] Specialist Agent is initializing - connecting to modal
# [2025-11-20 18:14:44 +0100] [Agents] [INFO] [Specialist Agent] Specialist Agent is initializing - connecting to modal
# [2025-11-20 18:14:44 +0100] [Agents] [INFO] [Specialist Agent] Specialist Agent is initializing - connecting to modal
# [2025-11-20 18:14:44 +0100] [Agents] [INFO] [Specialist Agent] Specialist Agent is initializing - connecting to modal
# [2025-11-20 18:14:44 +0100] [Agents] [INFO] [Specialist Agent] Specialist Agent is ready
# [2025-11-20 18:14:44 +0100] [Agents] [INFO] [Specialist Agent] Specialist Agent is ready
# [2025-11-20 18:14:44 +0100] [Agents] [INFO] [Specialist Agent] Specialist Agent is ready
# [2025-11-20 18:14:44 +0100] [Agents] [INFO] [Specialist Agent] Specialist Agent is ready
# [2025-11-20 18:14:44 +0100] [Agents] [INFO] [Frontier Agent] Initializing Frontier Agent
# [2025-11-20 18:14:44 +0100] [Agents] [INFO] [Frontier Agent] Initializing Frontier Agent
# [2025-11-20 18:14:44 +0100] [Agents] [INFO] [Frontier Agent] Initializing Frontier Agent
# [2025-11-20 18:14:44 +0100] [Agents] [INFO] [Frontier Agent] Initializing Frontier Agent
# [2025-11-20 18:14:44 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent is setting up with OpenAI
# [2025-11-20 18:14:44 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent is setting up with OpenAI
# [2025-11-20 18:14:44 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent is setting up with OpenAI
# [2025-11-20 18:14:44 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent is setting up with OpenAI
# [2025-11-20 18:14:44 +0100] [Agents] [INFO] Use pytorch device_name: cpu
# [2025-11-20 18:14:44 +0100] [Agents] [INFO] Use pytorch device_name: cpu
# [2025-11-20 18:14:44 +0100] [Agents] [INFO] Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# [2025-11-20 18:14:44 +0100] [Agents] [INFO] Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# [2025-11-20 18:14:44 +0100] [Agents] [INFO] Use pytorch device_name: cpu
# [2025-11-20 18:14:44 +0100] [Agents] [INFO] Use pytorch device_name: cpu
# [2025-11-20 18:14:44 +0100] [Agents] [INFO] Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# [2025-11-20 18:14:44 +0100] [Agents] [INFO] Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# [2025-11-20 18:14:46 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent is ready
# [2025-11-20 18:14:46 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent is ready
# [2025-11-20 18:14:46 +0100] [Agents] [INFO] [Random Forest Agent] Random Forest Agent is initializing
# [2025-11-20 18:14:46 +0100] [Agents] [INFO] [Random Forest Agent] Random Forest Agent is initializing
# [2025-11-20 18:14:46 +0100] [Agents] [INFO] Use pytorch device_name: cpu
# [2025-11-20 18:14:46 +0100] [Agents] [INFO] Use pytorch device_name: cpu
# [2025-11-20 18:14:46 +0100] [Agents] [INFO] Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# [2025-11-20 18:14:46 +0100] [Agents] [INFO] Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# [2025-11-20 18:14:46 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent is ready
# [2025-11-20 18:14:46 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent is ready
# [2025-11-20 18:14:46 +0100] [Agents] [INFO] [Random Forest Agent] Random Forest Agent is initializing
# [2025-11-20 18:14:46 +0100] [Agents] [INFO] [Random Forest Agent] Random Forest Agent is initializing
# [2025-11-20 18:14:46 +0100] [Agents] [INFO] Use pytorch device_name: cpu
# [2025-11-20 18:14:46 +0100] [Agents] [INFO] Use pytorch device_name: cpu
# [2025-11-20 18:14:46 +0100] [Agents] [INFO] Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# [2025-11-20 18:14:46 +0100] [Agents] [INFO] Load pretrained SentenceTransformer: sentence-transformers/all-MiniLM-L6-v2
# [2025-11-20 18:14:48 +0100] [Agents] [INFO] [Random Forest Agent] Random Forest Agent is ready
# [2025-11-20 18:14:48 +0100] [Agents] [INFO] [Random Forest Agent] Random Forest Agent is ready
# [2025-11-20 18:14:48 +0100] [Agents] [INFO] [Ensemble Agent] Ensemble Agent is ready
# [2025-11-20 18:14:48 +0100] [Agents] [INFO] [Ensemble Agent] Ensemble Agent is ready
# [2025-11-20 18:14:48 +0100] [Agents] [INFO] [Messaging Agent] Messaging Agent is initializing
# [2025-11-20 18:14:48 +0100] [Agents] [INFO] [Messaging Agent] Messaging Agent is initializing
# [2025-11-20 18:14:48 +0100] [Agents] [INFO] [Messaging Agent] Messaging Agent has initialized Pushover
# [2025-11-20 18:14:48 +0100] [Agents] [INFO] [Messaging Agent] Messaging Agent has initialized Pushover
# [2025-11-20 18:14:48 +0100] [Agents] [INFO] [Planning Agent] Planning Agent is ready
# [2025-11-20 18:14:48 +0100] [Agents] [INFO] [Planning Agent] Planning Agent is ready
# [2025-11-20 18:14:48 +0100] [Agents] [INFO] [Agent Framework] Agent Framework is ready
# [2025-11-20 18:14:48 +0100] [Agents] [INFO] [Agent Framework] Agent Framework is ready
# [2025-11-20 18:14:48 +0100] [Agents] [INFO] Kicking off Planning Agent
# [2025-11-20 18:14:48 +0100] [Agents] [INFO] Kicking off Planning Agent
# [2025-11-20 18:14:48 +0100] [Agents] [INFO] [Planning Agent] Planning Agent is kicking off a run
# [2025-11-20 18:14:48 +0100] [Agents] [INFO] [Planning Agent] Planning Agent is kicking off a run
# [2025-11-20 18:14:48 +0100] [Agents] [INFO] [Scanner Agent] Scanner Agent is about to fetch deals from RSS feed
# [2025-11-20 18:14:48 +0100] [Agents] [INFO] [Scanner Agent] Scanner Agent is about to fetch deals from RSS feed
# [2025-11-20 18:14:48 +0100] [Agents] [INFO] [Random Forest Agent] Random Forest Agent is ready
# [2025-11-20 18:14:48 +0100] [Agents] [INFO] [Random Forest Agent] Random Forest Agent is ready
# [2025-11-20 18:14:48 +0100] [Agents] [INFO] [Ensemble Agent] Ensemble Agent is ready
# [2025-11-20 18:14:48 +0100] [Agents] [INFO] [Ensemble Agent] Ensemble Agent is ready
# [2025-11-20 18:14:48 +0100] [Agents] [INFO] [Messaging Agent] Messaging Agent is initializing
# [2025-11-20 18:14:48 +0100] [Agents] [INFO] [Messaging Agent] Messaging Agent is initializing
# [2025-11-20 18:14:48 +0100] [Agents] [INFO] [Messaging Agent] Messaging Agent has initialized Pushover
# [2025-11-20 18:14:48 +0100] [Agents] [INFO] [Messaging Agent] Messaging Agent has initialized Pushover
# [2025-11-20 18:14:48 +0100] [Agents] [INFO] [Planning Agent] Planning Agent is ready
# [2025-11-20 18:14:48 +0100] [Agents] [INFO] [Planning Agent] Planning Agent is ready
# [2025-11-20 18:14:48 +0100] [Agents] [INFO] [Agent Framework] Agent Framework is ready
# [2025-11-20 18:14:48 +0100] [Agents] [INFO] [Agent Framework] Agent Framework is ready
# [2025-11-20 18:16:11 +0100] [Agents] [INFO] [Messaging Agent] Messaging Agent is sending a push notification
# [2025-11-20 18:16:11 +0100] [Agents] [INFO] [Messaging Agent] Messaging Agent is sending a push notification
# [2025-11-20 18:16:12 +0100] [Agents] [INFO] [Messaging Agent] Messaging Agent has completed
# [2025-11-20 18:16:12 +0100] [Agents] [INFO] [Messaging Agent] Messaging Agent has completed
# [2025-11-20 18:17:35 +0100] [Agents] [INFO] [Scanner Agent] Scanner Agent received 20 deals not already scraped
# [2025-11-20 18:17:35 +0100] [Agents] [INFO] [Scanner Agent] Scanner Agent received 20 deals not already scraped
# [2025-11-20 18:17:35 +0100] [Agents] [INFO] [Scanner Agent] Scanner Agent is calling OpenAI using Structured Output
# [2025-11-20 18:17:35 +0100] [Agents] [INFO] [Scanner Agent] Scanner Agent is calling OpenAI using Structured Output
# [2025-11-20 18:18:02 +0100] [Agents] [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2025-11-20 18:18:02 +0100] [Agents] [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2025-11-20 18:18:02 +0100] [Agents] [INFO] [Scanner Agent] Scanner Agent received 5 selected deals with price>0 from OpenAI
# [2025-11-20 18:18:02 +0100] [Agents] [INFO] [Scanner Agent] Scanner Agent received 5 selected deals with price>0 from OpenAI
# [2025-11-20 18:18:02 +0100] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2025-11-20 18:18:02 +0100] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2025-11-20 18:18:02 +0100] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - collaborating with specialist, frontier and random forest agents
# [2025-11-20 18:18:02 +0100] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - collaborating with specialist, frontier and random forest agents
# [2025-11-20 18:18:02 +0100] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2025-11-20 18:18:02 +0100] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2025-11-20 18:19:02 +0100] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $799.00
# [2025-11-20 18:19:02 +0100] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $799.00
# [2025-11-20 18:19:02 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# [2025-11-20 18:19:02 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# Batches: 100%|████████████████████████████████████| 1/1 [00:00<00:00, 10.92it/s]
# [2025-11-20 18:19:02 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2025-11-20 18:19:02 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2025-11-20 18:19:02 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call gpt-4o-mini with context including 5 similar products
# [2025-11-20 18:19:02 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call gpt-4o-mini with context including 5 similar products
# [2025-11-20 18:19:03 +0100] [Agents] [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2025-11-20 18:19:03 +0100] [Agents] [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2025-11-20 18:19:03 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $599.99
# [2025-11-20 18:19:03 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $599.99
# [2025-11-20 18:19:03 +0100] [Agents] [INFO] [Random Forest Agent] Random Forest Agent is starting a prediction
# [2025-11-20 18:19:03 +0100] [Agents] [INFO] [Random Forest Agent] Random Forest Agent is starting a prediction
# Batches: 100%|████████████████████████████████████| 1/1 [00:00<00:00, 15.03it/s]
# [2025-11-20 18:19:04 +0100] [Agents] [INFO] [Random Forest Agent] Random Forest Agent completed - predicting $98.15
# [2025-11-20 18:19:04 +0100] [Agents] [INFO] [Random Forest Agent] Random Forest Agent completed - predicting $98.15
# [2025-11-20 18:19:04 +0100] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $780.36
# [2025-11-20 18:19:04 +0100] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $780.36
# [2025-11-20 18:19:04 +0100] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $530.36
# [2025-11-20 18:19:04 +0100] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $530.36
# [2025-11-20 18:19:04 +0100] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2025-11-20 18:19:04 +0100] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2025-11-20 18:19:04 +0100] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - collaborating with specialist, frontier and random forest agents
# [2025-11-20 18:19:04 +0100] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - collaborating with specialist, frontier and random forest agents
# [2025-11-20 18:19:04 +0100] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2025-11-20 18:19:04 +0100] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2025-11-20 18:19:05 +0100] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $400.00
# [2025-11-20 18:19:05 +0100] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $400.00
# [2025-11-20 18:19:05 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# [2025-11-20 18:19:05 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# Batches: 100%|████████████████████████████████████| 1/1 [00:00<00:00, 16.11it/s]
# [2025-11-20 18:19:06 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2025-11-20 18:19:06 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2025-11-20 18:19:06 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call gpt-4o-mini with context including 5 similar products
# [2025-11-20 18:19:06 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call gpt-4o-mini with context including 5 similar products
# [2025-11-20 18:19:06 +0100] [Agents] [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2025-11-20 18:19:06 +0100] [Agents] [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2025-11-20 18:19:06 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $299.99
# [2025-11-20 18:19:06 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $299.99
# [2025-11-20 18:19:06 +0100] [Agents] [INFO] [Random Forest Agent] Random Forest Agent is starting a prediction
# [2025-11-20 18:19:06 +0100] [Agents] [INFO] [Random Forest Agent] Random Forest Agent is starting a prediction
# Batches: 100%|████████████████████████████████████| 1/1 [00:00<00:00, 15.02it/s]
# [2025-11-20 18:19:06 +0100] [Agents] [INFO] [Random Forest Agent] Random Forest Agent completed - predicting $112.55
# [2025-11-20 18:19:06 +0100] [Agents] [INFO] [Random Forest Agent] Random Forest Agent completed - predicting $112.55
# [2025-11-20 18:19:06 +0100] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $389.13
# [2025-11-20 18:19:06 +0100] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $389.13
# [2025-11-20 18:19:06 +0100] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $-9.87
# [2025-11-20 18:19:06 +0100] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $-9.87
# [2025-11-20 18:19:06 +0100] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2025-11-20 18:19:06 +0100] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2025-11-20 18:19:06 +0100] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - collaborating with specialist, frontier and random forest agents
# [2025-11-20 18:19:06 +0100] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - collaborating with specialist, frontier and random forest agents
# [2025-11-20 18:19:06 +0100] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2025-11-20 18:19:06 +0100] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2025-11-20 18:19:08 +0100] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $199.00
# [2025-11-20 18:19:08 +0100] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $199.00
# [2025-11-20 18:19:08 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# [2025-11-20 18:19:08 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# Batches: 100%|████████████████████████████████████| 1/1 [00:00<00:00, 30.91it/s]
# [2025-11-20 18:19:08 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2025-11-20 18:19:08 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2025-11-20 18:19:08 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call gpt-4o-mini with context including 5 similar products
# [2025-11-20 18:19:08 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call gpt-4o-mini with context including 5 similar products
# [2025-11-20 18:19:09 +0100] [Agents] [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2025-11-20 18:19:09 +0100] [Agents] [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2025-11-20 18:19:09 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $199.00
# [2025-11-20 18:19:09 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $199.00
# [2025-11-20 18:19:09 +0100] [Agents] [INFO] [Random Forest Agent] Random Forest Agent is starting a prediction
# [2025-11-20 18:19:09 +0100] [Agents] [INFO] [Random Forest Agent] Random Forest Agent is starting a prediction
# Batches: 100%|████████████████████████████████████| 1/1 [00:00<00:00, 10.37it/s]
# [2025-11-20 18:19:09 +0100] [Agents] [INFO] [Random Forest Agent] Random Forest Agent completed - predicting $273.16
# [2025-11-20 18:19:09 +0100] [Agents] [INFO] [Random Forest Agent] Random Forest Agent completed - predicting $273.16
# [2025-11-20 18:19:09 +0100] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $209.60
# [2025-11-20 18:19:09 +0100] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $209.60
# [2025-11-20 18:19:09 +0100] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $139.60
# [2025-11-20 18:19:09 +0100] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $139.60
# [2025-11-20 18:19:09 +0100] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2025-11-20 18:19:09 +0100] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2025-11-20 18:19:09 +0100] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - collaborating with specialist, frontier and random forest agents
# [2025-11-20 18:19:09 +0100] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - collaborating with specialist, frontier and random forest agents
# [2025-11-20 18:19:09 +0100] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2025-11-20 18:19:09 +0100] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2025-11-20 18:19:11 +0100] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $700.00
# [2025-11-20 18:19:11 +0100] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $700.00
# [2025-11-20 18:19:11 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# [2025-11-20 18:19:11 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# Batches: 100%|████████████████████████████████████| 1/1 [00:00<00:00, 16.52it/s]
# [2025-11-20 18:19:11 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2025-11-20 18:19:11 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2025-11-20 18:19:11 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call gpt-4o-mini with context including 5 similar products
# [2025-11-20 18:19:11 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call gpt-4o-mini with context including 5 similar products
# [2025-11-20 18:19:11 +0100] [Agents] [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2025-11-20 18:19:11 +0100] [Agents] [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2025-11-20 18:19:11 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $599.99
# [2025-11-20 18:19:11 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $599.99
# [2025-11-20 18:19:11 +0100] [Agents] [INFO] [Random Forest Agent] Random Forest Agent is starting a prediction
# [2025-11-20 18:19:11 +0100] [Agents] [INFO] [Random Forest Agent] Random Forest Agent is starting a prediction
# Batches: 100%|████████████████████████████████████| 1/1 [00:00<00:00, 17.44it/s]
# [2025-11-20 18:19:11 +0100] [Agents] [INFO] [Random Forest Agent] Random Forest Agent completed - predicting $250.16
# [2025-11-20 18:19:11 +0100] [Agents] [INFO] [Random Forest Agent] Random Forest Agent completed - predicting $250.16
# [2025-11-20 18:19:11 +0100] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $697.39
# [2025-11-20 18:19:11 +0100] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $697.39
# [2025-11-20 18:19:11 +0100] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $-2.61
# [2025-11-20 18:19:11 +0100] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $-2.61
# [2025-11-20 18:19:11 +0100] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2025-11-20 18:19:11 +0100] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2025-11-20 18:19:11 +0100] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - collaborating with specialist, frontier and random forest agents
# [2025-11-20 18:19:11 +0100] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - collaborating with specialist, frontier and random forest agents
# [2025-11-20 18:19:11 +0100] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2025-11-20 18:19:11 +0100] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2025-11-20 18:19:13 +0100] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $220.00
# [2025-11-20 18:19:13 +0100] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $220.00
# [2025-11-20 18:19:13 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# [2025-11-20 18:19:13 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# Batches: 100%|████████████████████████████████████| 1/1 [00:00<00:00, 19.93it/s]
# [2025-11-20 18:19:13 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2025-11-20 18:19:13 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2025-11-20 18:19:13 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call gpt-4o-mini with context including 5 similar products
# [2025-11-20 18:19:13 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call gpt-4o-mini with context including 5 similar products
# [2025-11-20 18:19:14 +0100] [Agents] [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2025-11-20 18:19:14 +0100] [Agents] [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2025-11-20 18:19:14 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $59.99
# [2025-11-20 18:19:14 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $59.99
# [2025-11-20 18:19:14 +0100] [Agents] [INFO] [Random Forest Agent] Random Forest Agent is starting a prediction
# [2025-11-20 18:19:14 +0100] [Agents] [INFO] [Random Forest Agent] Random Forest Agent is starting a prediction
# Batches: 100%|████████████████████████████████████| 1/1 [00:00<00:00, 16.50it/s]
# [2025-11-20 18:19:14 +0100] [Agents] [INFO] [Random Forest Agent] Random Forest Agent completed - predicting $88.31
# [2025-11-20 18:19:14 +0100] [Agents] [INFO] [Random Forest Agent] Random Forest Agent completed - predicting $88.31
# [2025-11-20 18:19:14 +0100] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $189.21
# [2025-11-20 18:19:14 +0100] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $189.21
# [2025-11-20 18:19:14 +0100] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $130.21
# [2025-11-20 18:19:14 +0100] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $130.21
# [2025-11-20 18:19:14 +0100] [Agents] [INFO] [Planning Agent] Planning Agent has identified the best deal has discount $530.36
# [2025-11-20 18:19:14 +0100] [Agents] [INFO] [Planning Agent] Planning Agent has identified the best deal has discount $530.36
# [2025-11-20 18:19:14 +0100] [Agents] [INFO] [Messaging Agent] Messaging Agent is sending a push notification
# [2025-11-20 18:19:14 +0100] [Agents] [INFO] [Messaging Agent] Messaging Agent is sending a push notification
# [2025-11-20 18:19:15 +0100] [Agents] [INFO] [Messaging Agent] Messaging Agent has completed
# [2025-11-20 18:19:15 +0100] [Agents] [INFO] [Messaging Agent] Messaging Agent has completed
# [2025-11-20 18:19:15 +0100] [Agents] [INFO] [Planning Agent] Planning Agent has completed a run
# [2025-11-20 18:19:15 +0100] [Agents] [INFO] [Planning Agent] Planning Agent has completed a run
# [2025-11-20 18:19:15 +0100] [Agents] [INFO] Planning Agent has completed and returned: deal=Deal(product_description='The Toshiba M550 Series 55M550NU is a 55-inch QLED 4K UHD Fire TV that delivers stunning picture quality with 4K resolution. It features advanced HDR technologies such as Dolby Vision, HDR 10, and HLG for vibrant colors and deep contrast. With a sleek design, the TV integrates seamlessly into any living space and is equipped with Amazon Alexa and Apple HomeKit compatibility. Connectivity options include four HDMI inputs, allowing for easy connection to various devices.', price=250.0, url='https://www.dealnews.com/products/Toshiba/Toshiba-M550-Series-55-M550-NU-55-QLED-4-K-UHD-Fire-TV/489273.html?iref=rss-f1912') estimate=780.3637769855893 discount=530.3637769855893
# [2025-11-20 18:19:15 +0100] [Agents] [INFO] Planning Agent has completed and returned: deal=Deal(product_description='The Toshiba M550 Series 55M550NU is a 55-inch QLED 4K UHD Fire TV that delivers stunning picture quality with 4K resolution. It features advanced HDR technologies such as Dolby Vision, HDR 10, and HLG for vibrant colors and deep contrast. With a sleek design, the TV integrates seamlessly into any living space and is equipped with Amazon Alexa and Apple HomeKit compatibility. Connectivity options include four HDMI inputs, allowing for easy connection to various devices.', price=250.0, url='https://www.dealnews.com/products/Toshiba/Toshiba-M550-Series-55-M550-NU-55-QLED-4-K-UHD-Fire-TV/489273.html?iref=rss-f1912') estimate=780.3637769855893 discount=530.3637769855893
# [2025-11-20 18:19:29 +0100] [Agents] [INFO] [Messaging Agent] Messaging Agent is sending a push notification
# [2025-11-20 18:19:29 +0100] [Agents] [INFO] [Messaging Agent] Messaging Agent is sending a push notification
# [2025-11-20 18:19:29 +0100] [Agents] [INFO] [Messaging Agent] Messaging Agent has completed
# [2025-11-20 18:19:29 +0100] [Agents] [INFO] [Messaging Agent] Messaging Agent has completed
# [2025-11-20 18:19:44 +0100] [Agents] [INFO] Kicking off Planning Agent
# [2025-11-20 18:19:44 +0100] [Agents] [INFO] Kicking off Planning Agent
# [2025-11-20 18:19:44 +0100] [Agents] [INFO] [Planning Agent] Planning Agent is kicking off a run
# [2025-11-20 18:19:44 +0100] [Agents] [INFO] [Planning Agent] Planning Agent is kicking off a run
# [2025-11-20 18:19:44 +0100] [Agents] [INFO] [Scanner Agent] Scanner Agent is about to fetch deals from RSS feed
# [2025-11-20 18:19:44 +0100] [Agents] [INFO] [Scanner Agent] Scanner Agent is about to fetch deals from RSS feed
# [2025-11-20 18:22:07 +0100] [Agents] [INFO] [Scanner Agent] Scanner Agent received 19 deals not already scraped
# [2025-11-20 18:22:07 +0100] [Agents] [INFO] [Scanner Agent] Scanner Agent received 19 deals not already scraped
# [2025-11-20 18:22:07 +0100] [Agents] [INFO] [Scanner Agent] Scanner Agent is calling OpenAI using Structured Output
# [2025-11-20 18:22:07 +0100] [Agents] [INFO] [Scanner Agent] Scanner Agent is calling OpenAI using Structured Output
# [2025-11-20 18:22:27 +0100] [Agents] [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2025-11-20 18:22:27 +0100] [Agents] [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2025-11-20 18:22:27 +0100] [Agents] [INFO] [Scanner Agent] Scanner Agent received 5 selected deals with price>0 from OpenAI
# [2025-11-20 18:22:27 +0100] [Agents] [INFO] [Scanner Agent] Scanner Agent received 5 selected deals with price>0 from OpenAI
# [2025-11-20 18:22:27 +0100] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2025-11-20 18:22:27 +0100] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2025-11-20 18:22:27 +0100] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - collaborating with specialist, frontier and random forest agents
# [2025-11-20 18:22:27 +0100] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - collaborating with specialist, frontier and random forest agents
# [2025-11-20 18:22:27 +0100] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2025-11-20 18:22:27 +0100] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2025-11-20 18:23:09 +0100] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $299.00
# [2025-11-20 18:23:09 +0100] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $299.00
# [2025-11-20 18:23:09 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# [2025-11-20 18:23:09 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# Batches: 100%|████████████████████████████████████| 1/1 [00:00<00:00, 17.15it/s]
# [2025-11-20 18:23:09 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2025-11-20 18:23:09 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2025-11-20 18:23:09 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call gpt-4o-mini with context including 5 similar products
# [2025-11-20 18:23:09 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call gpt-4o-mini with context including 5 similar products
# [2025-11-20 18:23:09 +0100] [Agents] [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2025-11-20 18:23:09 +0100] [Agents] [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2025-11-20 18:23:09 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $249.00
# [2025-11-20 18:23:09 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $249.00
# [2025-11-20 18:23:09 +0100] [Agents] [INFO] [Random Forest Agent] Random Forest Agent is starting a prediction
# [2025-11-20 18:23:09 +0100] [Agents] [INFO] [Random Forest Agent] Random Forest Agent is starting a prediction
# Batches: 100%|████████████████████████████████████| 1/1 [00:00<00:00, 15.93it/s]
# [2025-11-20 18:23:10 +0100] [Agents] [INFO] [Random Forest Agent] Random Forest Agent completed - predicting $267.51
# [2025-11-20 18:23:10 +0100] [Agents] [INFO] [Random Forest Agent] Random Forest Agent completed - predicting $267.51
# [2025-11-20 18:23:10 +0100] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $292.97
# [2025-11-20 18:23:10 +0100] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $292.97
# [2025-11-20 18:23:10 +0100] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $208.97
# [2025-11-20 18:23:10 +0100] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $208.97
# [2025-11-20 18:23:10 +0100] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2025-11-20 18:23:10 +0100] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2025-11-20 18:23:10 +0100] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - collaborating with specialist, frontier and random forest agents
# [2025-11-20 18:23:10 +0100] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - collaborating with specialist, frontier and random forest agents
# [2025-11-20 18:23:10 +0100] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2025-11-20 18:23:10 +0100] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2025-11-20 18:23:11 +0100] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $999.00
# [2025-11-20 18:23:11 +0100] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $999.00
# [2025-11-20 18:23:11 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# [2025-11-20 18:23:11 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# Batches: 100%|████████████████████████████████████| 1/1 [00:00<00:00, 19.11it/s]
# [2025-11-20 18:23:11 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2025-11-20 18:23:11 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2025-11-20 18:23:11 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call gpt-4o-mini with context including 5 similar products
# [2025-11-20 18:23:11 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call gpt-4o-mini with context including 5 similar products
# [2025-11-20 18:23:12 +0100] [Agents] [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2025-11-20 18:23:12 +0100] [Agents] [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2025-11-20 18:23:12 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $5999.00
# [2025-11-20 18:23:12 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $5999.00
# [2025-11-20 18:23:12 +0100] [Agents] [INFO] [Random Forest Agent] Random Forest Agent is starting a prediction
# [2025-11-20 18:23:12 +0100] [Agents] [INFO] [Random Forest Agent] Random Forest Agent is starting a prediction
# Batches: 100%|████████████████████████████████████| 1/1 [00:00<00:00, 15.02it/s]
# [2025-11-20 18:23:12 +0100] [Agents] [INFO] [Random Forest Agent] Random Forest Agent completed - predicting $136.33
# [2025-11-20 18:23:12 +0100] [Agents] [INFO] [Random Forest Agent] Random Forest Agent completed - predicting $136.33
# [2025-11-20 18:23:12 +0100] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $2564.83
# [2025-11-20 18:23:12 +0100] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $2564.83
# [2025-11-20 18:23:12 +0100] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $1566.83
# [2025-11-20 18:23:12 +0100] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $1566.83
# [2025-11-20 18:23:12 +0100] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2025-11-20 18:23:12 +0100] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2025-11-20 18:23:12 +0100] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - collaborating with specialist, frontier and random forest agents
# [2025-11-20 18:23:12 +0100] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - collaborating with specialist, frontier and random forest agents
# [2025-11-20 18:23:12 +0100] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2025-11-20 18:23:12 +0100] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2025-11-20 18:23:14 +0100] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $130.00
# [2025-11-20 18:23:14 +0100] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $130.00
# [2025-11-20 18:23:14 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# [2025-11-20 18:23:14 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# Batches: 100%|████████████████████████████████████| 1/1 [00:00<00:00, 26.80it/s]
# [2025-11-20 18:23:14 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2025-11-20 18:23:14 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2025-11-20 18:23:14 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call gpt-4o-mini with context including 5 similar products
# [2025-11-20 18:23:14 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call gpt-4o-mini with context including 5 similar products
# [2025-11-20 18:23:14 +0100] [Agents] [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2025-11-20 18:23:14 +0100] [Agents] [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2025-11-20 18:23:14 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $89.99
# [2025-11-20 18:23:14 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $89.99
# [2025-11-20 18:23:14 +0100] [Agents] [INFO] [Random Forest Agent] Random Forest Agent is starting a prediction
# [2025-11-20 18:23:14 +0100] [Agents] [INFO] [Random Forest Agent] Random Forest Agent is starting a prediction
# Batches: 100%|████████████████████████████████████| 1/1 [00:00<00:00, 37.88it/s]
# [2025-11-20 18:23:14 +0100] [Agents] [INFO] [Random Forest Agent] Random Forest Agent completed - predicting $164.12
# [2025-11-20 18:23:14 +0100] [Agents] [INFO] [Random Forest Agent] Random Forest Agent completed - predicting $164.12
# [2025-11-20 18:23:14 +0100] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $129.09
# [2025-11-20 18:23:14 +0100] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $129.09
# [2025-11-20 18:23:14 +0100] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $104.09
# [2025-11-20 18:23:14 +0100] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $104.09
# [2025-11-20 18:23:14 +0100] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2025-11-20 18:23:14 +0100] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2025-11-20 18:23:14 +0100] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - collaborating with specialist, frontier and random forest agents
# [2025-11-20 18:23:14 +0100] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - collaborating with specialist, frontier and random forest agents
# [2025-11-20 18:23:14 +0100] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2025-11-20 18:23:14 +0100] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2025-11-20 18:23:16 +0100] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $299.00
# [2025-11-20 18:23:16 +0100] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $299.00
# [2025-11-20 18:23:16 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# [2025-11-20 18:23:16 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# Batches: 100%|████████████████████████████████████| 1/1 [00:00<00:00, 17.74it/s]
# [2025-11-20 18:23:16 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2025-11-20 18:23:16 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2025-11-20 18:23:16 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call gpt-4o-mini with context including 5 similar products
# [2025-11-20 18:23:16 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call gpt-4o-mini with context including 5 similar products
# [2025-11-20 18:23:17 +0100] [Agents] [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2025-11-20 18:23:17 +0100] [Agents] [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2025-11-20 18:23:17 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $499.99
# [2025-11-20 18:23:17 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $499.99
# [2025-11-20 18:23:17 +0100] [Agents] [INFO] [Random Forest Agent] Random Forest Agent is starting a prediction
# [2025-11-20 18:23:17 +0100] [Agents] [INFO] [Random Forest Agent] Random Forest Agent is starting a prediction
# Batches: 100%|████████████████████████████████████| 1/1 [00:00<00:00, 17.59it/s]
# [2025-11-20 18:23:17 +0100] [Agents] [INFO] [Random Forest Agent] Random Forest Agent completed - predicting $120.75
# [2025-11-20 18:23:17 +0100] [Agents] [INFO] [Random Forest Agent] Random Forest Agent completed - predicting $120.75
# [2025-11-20 18:23:17 +0100] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $370.51
# [2025-11-20 18:23:17 +0100] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $370.51
# [2025-11-20 18:23:17 +0100] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $-28.49
# [2025-11-20 18:23:17 +0100] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $-28.49
# [2025-11-20 18:23:17 +0100] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2025-11-20 18:23:17 +0100] [Agents] [INFO] [Planning Agent] Planning Agent is pricing up a potential deal
# [2025-11-20 18:23:17 +0100] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - collaborating with specialist, frontier and random forest agents
# [2025-11-20 18:23:17 +0100] [Agents] [INFO] [Ensemble Agent] Running Ensemble Agent - collaborating with specialist, frontier and random forest agents
# [2025-11-20 18:23:17 +0100] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2025-11-20 18:23:17 +0100] [Agents] [INFO] [Specialist Agent] Specialist Agent is calling remote fine-tuned model
# [2025-11-20 18:23:18 +0100] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $220.00
# [2025-11-20 18:23:18 +0100] [Agents] [INFO] [Specialist Agent] Specialist Agent completed - predicting $220.00
# [2025-11-20 18:23:18 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# [2025-11-20 18:23:18 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent is performing a RAG search of the Chroma datastore to find 5 similar products
# Batches: 100%|████████████████████████████████████| 1/1 [00:00<00:00, 20.29it/s]
# [2025-11-20 18:23:18 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2025-11-20 18:23:18 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent has found similar products
# [2025-11-20 18:23:18 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call gpt-4o-mini with context including 5 similar products
# [2025-11-20 18:23:18 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent is about to call gpt-4o-mini with context including 5 similar products
# [2025-11-20 18:23:19 +0100] [Agents] [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2025-11-20 18:23:19 +0100] [Agents] [INFO] HTTP Request: POST https://api.openai.com/v1/chat/completions "HTTP/1.1 200 OK"
# [2025-11-20 18:23:19 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $149.99
# [2025-11-20 18:23:19 +0100] [Agents] [INFO] [Frontier Agent] Frontier Agent completed - predicting $149.99
# [2025-11-20 18:23:19 +0100] [Agents] [INFO] [Random Forest Agent] Random Forest Agent is starting a prediction
# [2025-11-20 18:23:19 +0100] [Agents] [INFO] [Random Forest Agent] Random Forest Agent is starting a prediction
# Batches: 100%|████████████████████████████████████| 1/1 [00:00<00:00, 20.08it/s]
# [2025-11-20 18:23:19 +0100] [Agents] [INFO] [Random Forest Agent] Random Forest Agent completed - predicting $139.35
# [2025-11-20 18:23:19 +0100] [Agents] [INFO] [Random Forest Agent] Random Forest Agent completed - predicting $139.35
# [2025-11-20 18:23:19 +0100] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $208.19
# [2025-11-20 18:23:19 +0100] [Agents] [INFO] [Ensemble Agent] Ensemble Agent complete - returning $208.19
# [2025-11-20 18:23:19 +0100] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $98.19
# [2025-11-20 18:23:19 +0100] [Agents] [INFO] [Planning Agent] Planning Agent has processed a deal with discount $98.19
# [2025-11-20 18:23:19 +0100] [Agents] [INFO] [Planning Agent] Planning Agent has identified the best deal has discount $1566.83
# [2025-11-20 18:23:19 +0100] [Agents] [INFO] [Planning Agent] Planning Agent has identified the best deal has discount $1566.83
# [2025-11-20 18:23:19 +0100] [Agents] [INFO] [Messaging Agent] Messaging Agent is sending a push notification
# [2025-11-20 18:23:19 +0100] [Agents] [INFO] [Messaging Agent] Messaging Agent is sending a push notification
# [2025-11-20 18:23:19 +0100] [Agents] [INFO] [Messaging Agent] Messaging Agent has completed
# [2025-11-20 18:23:19 +0100] [Agents] [INFO] [Messaging Agent] Messaging Agent has completed
# [2025-11-20 18:23:19 +0100] [Agents] [INFO] [Planning Agent] Planning Agent has completed a run
# [2025-11-20 18:23:19 +0100] [Agents] [INFO] [Planning Agent] Planning Agent has completed a run
# [2025-11-20 18:23:19 +0100] [Agents] [INFO] Planning Agent has completed and returned: deal=Deal(product_description='The TCL Q Series 98Q51CG is a massive 98" 4K QLED UHD Smart TV, providing stunning visuals with a resolution of 3840x2160. It features advanced HDR technology, including HDR10, HLG, and Dolby Vision IQ, for vibrant colors and contrast. This TV is powered by Google TV OS, boasting built-in Google Assistant and Chromecast support for seamless streaming and control. With a 144Hz refresh rate and multiple HDMI inputs, this television is perfect for gaming and viewing enjoyment.', price=998.0, url='https://www.dealnews.com/TCL-Q-Series-98-Q51-CG-98-4-K-QLED-UHD-Smart-TV-for-998-free-shipping/21786089.html?iref=rss-f1912') estimate=2564.8276712907627 discount=1566.8276712907627
# [2025-11-20 18:23:19 +0100] [Agents] [INFO] Planning Agent has completed and returned: deal=Deal(product_description='The TCL Q Series 98Q51CG is a massive 98" 4K QLED UHD Smart TV, providing stunning visuals with a resolution of 3840x2160. It features advanced HDR technology, including HDR10, HLG, and Dolby Vision IQ, for vibrant colors and contrast. This TV is powered by Google TV OS, boasting built-in Google Assistant and Chromecast support for seamless streaming and control. With a 144Hz refresh rate and multiple HDMI inputs, this television is perfect for gaming and viewing enjoyment.', price=998.0, url='https://www.dealnews.com/TCL-Q-Series-98-Q51-CG-98-4-K-QLED-UHD-Smart-TV-for-998-free-shipping/21786089.html?iref=rss-f1912') estimate=2564.8276712907627 discount=1566.8276712907627
# [2025-11-20 18:24:44 +0100] [Agents] [INFO] Kicking off Planning Agent
# [2025-11-20 18:24:44 +0100] [Agents] [INFO] Kicking off Planning Agent
# [2025-11-20 18:24:44 +0100] [Agents] [INFO] [Planning Agent] Planning Agent is kicking off a run
# [2025-11-20 18:24:44 +0100] [Agents] [INFO] [Planning Agent] Planning Agent is kicking off a run
# [2025-11-20 18:24:44 +0100] [Agents] [INFO] [Scanner Agent] Scanner Agent is about to fetch deals from RSS feed
# [2025-11-20 18:24:44 +0100] [Agents] [INFO] [Scanner Agent] Scanner Agent is about to fetch deals from RSS feed
# ^C
# Traceback (most recent call last):
#   File "/opt/miniconda3/envs/llms/lib/python3.11/site-packages/gradio/blocks.py", line 3022, in block_thread
#     time.sleep(0.1)
# KeyboardInterrupt
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/florianvanhee/Documents/AI/my_llm_engineering/week8/price_is_right_final.py", line 165, in <module>
#     App().run()
#   File "/Users/florianvanhee/Documents/AI/my_llm_engineering/week8/price_is_right_final.py", line 162, in run
#     ui.launch(share=False, inbrowser=True)
#   File "/opt/miniconda3/envs/llms/lib/python3.11/site-packages/gradio/blocks.py", line 2919, in launch
#     self.block_thread()
#   File "/opt/miniconda3/envs/llms/lib/python3.11/site-packages/gradio/blocks.py", line 3026, in block_thread
#     self.server.close()
#   File "/opt/miniconda3/envs/llms/lib/python3.11/site-packages/gradio/http_server.py", line 69, in close
#     self.thread.join(timeout=5)
#   File "/opt/miniconda3/envs/llms/lib/python3.11/threading.py", line 1123, in join
#     self._wait_for_tstate_lock(timeout=max(timeout, 0))
#   File "/opt/miniconda3/envs/llms/lib/python3.11/threading.py", line 1139, in _wait_for_tstate_lock
#     if lock.acquire(block, timeout):
#        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# KeyboardInterrupt

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/important.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#900;">But wait!! There's more..</h2>
#             <span style="color:#900;">If you're not fed up of product prices yet 😂 I've built this out some more!<br/>
#             If you look in my repo <a href="https://github.com/ed-donner/tech2ai">tech2ai</a>, in segment3/lab1 is a neural network implementation of the pricer in pure PyTorch. It does pretty well..<br/>
#             And if you look in my repo <a href="https://github.com/ed-donner/agentic">Agentic</a> in the workshop folder is the same Agent project taken further. There's a new version of the PlanningAgent called AutonomousPlanningAgent that uses multiple Tools, and a MessagingAgent that uses claude-3.7 to write texts. The AutonomousPlanningAgent uses the fantastic OpenAI Agents SDK and the mighty MCP protocol from Anthropic.<br/>
#             If you're intrigued by Agents and MCP, and would like to learn more, then I also have a <a href="https://edwarddonner.com/2025/05/28/connecting-my-courses-become-an-llm-expert-and-leader/">companion course called the Complete Agentic AI Engineering Course</a> that might interest you (if you haven't had enough of me by now!!), and also another course for leaders and founders looking to build a valuable business with LLMs.
#             </span>
#         </td>
#     </tr>
# </table>

# %% [markdown]
# <table style="margin: 0; text-align: left;">
#     <tr>
#         <td style="width: 150px; height: 150px; vertical-align: middle;">
#             <img src="../assets/thankyou.jpg" width="150" height="150" style="display: block;" />
#         </td>
#         <td>
#             <h2 style="color:#090;">CONGRATULATIONS AND THANK YOU!!!</h2>
#             <span style="color:#090;">
#                 It's so fabulous that you've made it to the very end! My heartiest congratulations. Please stay in touch! I'm <a href="https://www.linkedin.com/in/eddonner/">here on LinkedIn</a> if we're not already connected and I'm on X at <a href="https://x.com/edwarddonner">@edwarddonner</a>. And my editor would be cross with me if I didn't mention one more time: it makes a HUGE difference when students rate this course on Udemy - it's one of the main ways that Udemy decides whether to show it to others. <br/><br/>Massive thanks again for putting up with me for 8 weeks and getting all the way to the final cell! I'm excited to hear all about your career as an LLM Engineer. If you post on LinkedIn about completing the course and tag me, then I'll weigh in to amplify your achievement. <br/><b>You could not have picked a better time to be in this field.</b>
#             </span>
#         </td>
#     </tr>
# </table>
